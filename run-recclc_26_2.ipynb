# %%
# !git clone https://github.com/hoang2306/CLCRec_run.git
# Out:
# Cloning into 'CLCRec_run'...
# remote: Enumerating objects: 156, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 156 (delta 32), reused 38 (delta 24), pack-reused 109 (from 2)
# Receiving objects: 100% (156/156), 40.65 MiB | 35.55 MiB/s, done.
# Resolving deltas: 100% (69/69), done.

# %%
# !git pull
# Out:
# fatal: not a git repository (or any parent up to mount point /kaggle)
# Stopping at filesystem boundary (GIT_DISCOVERY_ACROSS_FILESYSTEM not set).

# %%
cd CLCRec_run
# Out:
# /kaggle/working/CLCRec_run

# %%
mkdir Data

# %%
# !cp -r /kaggle/input/baby-format-clcrec/baby /kaggle/working/CLCRec_run/Data
# !cp -r /kaggle/input/movielens-clcrec/movielens /kaggle/working/CLCRec_run/Data
# !cp -r /kaggle/input/sports-clcrec/sports /kaggle/working/CLCRec_run/Data
# !cp -r /kaggle/input/clothing/clothing /kaggle/working/CLCRec_run/Data

# %%
# !python main.py --exp_mode ff --data_path=clothing --dim_E=64 --topK=20 --num_workers =4 --num_neg=512 --batch_size=2048 --temp_value=0.5 --lr_lambda=0.5 --l_r=5e-4
# Out:
# 2025-02-26 06:30:27.160968: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-26 06:30:27.185965: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-26 06:30:27.192924: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Data loading ...
# Data has been loaded.
# Now, training start ...
# 219136it [01:38, 2220.42it/s]
# ----------------- loss value:5.545673980891148  model_loss value:6.243636247153594 contrastive_loss value:0.0 reg_loss value:0.0036443030727139423 --------------
# Train start...
# ...

# %%
# !python main.py --exp_mode ff --data_path=clothing --dim_E=128 --topK=20 --num_workers=4 --num_neg=512 --batch_size=2048 --temp_value=0.5 --lr_lambda=0.01 --l_r=5e-3
# Out:
# 2025-02-26 02:34:00.024794: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-26 02:34:00.046879: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-26 02:34:00.054262: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Data loading ...
# Data has been loaded.
# Now, training start ...
# 219136it [01:40, 2178.66it/s]
# ----------------- loss value:6.1543757046494525  model_loss value:6.160742046677064 contrastive_loss value:0.0 reg_loss value:0.030548617222006913 --------------
# Train start...
# ...

# %%
# !python main.py --exp_mode ff --data_path=clothing --dim_E=128 --topK=20 --num_workers=4 --num_neg=512 --batch_size=2048 --temp_value=0.5 --lr_lambda=0.01 --l_r=2e-3
# Out:
# 2025-02-26 03:33:16.104927: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2025-02-26 03:33:16.128516: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2025-02-26 03:33:16.135189: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Data loading ...
# Data has been loaded.
# Now, training start ...
# 219136it [01:40, 2171.87it/s]
# ----------------- loss value:6.181534504221979  model_loss value:6.19156186380119 contrastive_loss value:0.0 reg_loss value:0.01211121771919811 --------------
# Train start...
# ...

# %%
# !python main.py --has_v True --has_t True --exp_mode fm --data_path baby --l_r 1e-2
# !python main.py --data_path=movielens --num_workers=4 --num_neg=512 --batch_size=512 --temp_value=2 --lr_lambda=0.5

# %%
# !python main.py --exp_mode fm --data_path=baby --dim_E=64 --topK=20 --num_workers=8 --num_neg=512 --batch_size=2048 --temp_value=1 --lr_lambda=0.02 --l_r=2e-3

# %%
# !python main.py --exp_mode ff --data_path=baby --topK=20 --num_workers=4 --num_neg=512 --batch_size=2048 --temp_value=0.5 --lr_lambda=0.01 --l_r=5e-3

# %%
# !python main.py --exp_mode ff --data_path=sports --topK=20 --num_workers=4 --num_neg=512 --batch_size=2048 --temp_value=0.5 --lr_lambda=0.01 --l_r=5e-3

# %%
# !python main.py --exp_mode ff --data_path=sports --topK=20 --num_workers=4 --num_neg=512 --batch_size=2048 --temp_value=0.5 --lr_lambda=0.01 --l_r=1e-3

# %%
# !python main.py --model_name='CLCRec' --l_r=0.001 --reg_weight=0.1 --num_workers=4 --num_neg=128 --has_a=True --has_t=True --lr_lambda=0.5 --temp_value=2.0 --num_sample=0.5
